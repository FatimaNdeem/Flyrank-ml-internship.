# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FatimaNdeem/Flyrank-ml-internship./blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that should be refreshed before they lose more traffic. During Week 1, I learned how machine learning can rank pages that are likely to be declining and help prioritize them for review. This lane is useful because it can help content teams decide which pages to update first instead of reviewing every page manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Question: Which webpages should be prioritized for content refresh to reduce traffic decline?
#
# Decision: Decide which webpages should be refreshed first.
#
# Action: The SEO or content team updates the highest-priority pages before spending time on pages that are already performing well.
#
# Cost of a wrong recommendation: If the model recommends the wrong pages, important declining pages may continue losing traffic, while time and effort may be wasted updating pages that do not actually need refreshing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 anonymized webpages with 44 features related to search performance and content quality. My initial analysis showed that the correlation between search volume and impressions was only 0.001, suggesting that search volume alone does not explain page performance. This indicates that multiple factors influence page performance, making the Refresh / Content Opportunity Scoring lane worth exploring.

# %%
import os, subprocess

if not os.path.exists("flyrank-ml-internship-starter"):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
    ])

os.chdir("flyrank-ml-internship-starter")
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show basic information
print("Number of pages:", df.shape[0])
print("Number of features:", df.shape[1])

# Calculate correlation
corr = df["search_volume"].corr(df["impressions_90d"])
print("Correlation between search volume and impressions:", round(corr, 3))
# Out:
# Number of pages: 30000
# Number of features: 44
# Correlation between search volume and impressions: 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project will provide decision support by identifying pages that may benefit from a content refresh based on patterns observed in the data. The results will show observed and directional relationships rather than certainty. This work cannot provide causal proof that refreshing a page will improve its rankings, nor can it predict or explain Google's ranking algorithm. Instead, it provides recommendations that should be reviewed before making decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
